# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:\\Users\\DELL\\Numpy\ls.csv")
data
# Out:
#       ID                 Area       City  \
# 0    211          Koramangala  Bangalore
# 1    221          Koramangala  Bangalore
# 2    246            Jogupalya  Bangalore
# 3    248          Indiranagar  Bangalore
# 4    249          Indiranagar  Bangalore
# 5    254          Indiranagar  Bangalore
# 6    258          Indiranagar  Bangalore
# 7    263          Koramangala  Bangalore
# 8    267               Domlur  Bangalore
# 9    308          Koramangala  Bangalore
# 10   435          Koramangala  Bangalore
# 11   446           Cooke Town  Bangalore
# 12   453      Pulikeshi Nagar  Bangalore
# 13   464  Sivanchetti Gardens  Bangalore
# 14   504            Kodihalli  Bangalore
# 15   604          Koramangala  Bangalore
# 16   608               Domlur  Bangalore
# 17   621          Indiranagar  Bangalore
# 18  1050            Jayanagar  Bangalore
# 19  1299           Film Nagar  Hyderabad
#
#                                       Restaurant  Price  Avg ratings  \
# ...

# %%
data.isnull().sum()
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Food type        0
# Address          0
# Delivery time    0
# dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'Area', 'City', 'Restaurant', 'Price', 'Avg ratings',
#        'Total ratings', 'Food type', 'Address', 'Delivery time'],
#       dtype='object')

# %%
data["Restaurant"].unique()
# Out:
# array(['Tandoor Hut', 'Tunday Kababi', 'Kim Lee', 'New Punjabi Hotel',
#        'Nh8', 'Treat', 'Chinita Real Mexican Food',
#        'Cupcake Noggins - Cakespastries And Desserts', 'Tea Brew',
#        'Bangaliana', "Bamey'S Restro Cafe",
#        "Altaf'S Chillies Restaurants", 'Chichabas Taj', 'Urban Solace',
#        'Kaati Zone Rolls & Wraps', 'Aalishan Restaurant & Caterer',
#        'Kerala Pavilion', 'Kitchen Of Joy', 'Nagarjuna Chimney',
#        'So. The Sky Kitchen'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data1=['ID', 'Area', 'City', 'Restaurant', 'Price', 'Avg ratings',
       'Total ratings', 'Food type', 'Address', 'Delivery time']
for i in data1:
    data[i]=le.fit_transform(data[i])
data
# Out:
#     ID  Area  City  Restaurant  Price  Avg ratings  Total ratings  Food type  \
# 0    0     7     0          15      3            6              2          4
# 1    1     7     0          18      3            3              2         11
# 2    2     5     0           9      8            6              2          5
# 3    3     3     0          12      1            1              3         16
# 4    4     3     0          13      4            2              0         17
# 5    5     3     0          17      9            7              2         12
# 6    6     3     0           5     10            7              3         10
# 7    7     7     0           6      0            5              2          7
# 8    8     1     0          16      4            3              2          1
# 9    9     7     0           3      3            2              3          2
# 10  10     7     0           2      5            6              2          6
# ...

# %%
x=data.drop("Restaurant",axis=1)
x
# Out:
#     ID  Area  City  Price  Avg ratings  Total ratings  Food type  Address  \
# 0    0     7     0      3            6              2          4        3
# 1    1     7     0      3            3              2         11        3
# 2    2     5     0      8            6              2          5        9
# 3    3     3     0      1            1              3         16        5
# 4    4     3     0      4            2              0         17        5
# 5    5     3     0      9            7              2         12        0
# 6    6     3     0     10            7              3         10        9
# 7    7     7     0      0            5              2          7        2
# 8    8     1     0      4            3              2          1        9
# 9    9     7     0      3            2              3          2        4
# 10  10     7     0      5            6              2          6        3
# 11  11     0     0      1            5              3         15        6
# ...

# %%
y=data["Restaurant"]
y
# Out:
# 0     15
# 1     18
# 2      9
# 3     12
# 4     13
# 5     17
# 6      5
# 7      6
# 8     16
# 9      3
# 10     2
# 11     1
# 12     4
# 13    19
# 14     7
# 15     0
# 16     8
# 17    10
# 18    11
# 19    14
# Name: Restaurant, dtype: int32

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30)

# %%
from sklearn.linear_model import LogisticRegression
r=LogisticRegression()
r.fit(xtrain,ytrain)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
d=r.predict(xtest)
d
# Out:
# array([10,  2, 12,  2,  8,  9])

# %%
y=accuracy_score(ytest,d)*100
y
# Out:
# 0.0

# %%
r1=r.predict(xtrain)
r1
# Out:
# array([ 4, 12,  9,  5, 17,  7, 18, 10, 13,  0,  8,  2, 15, 11])

# %%
r5=accuracy_score(ytrain,r1)*100
r5
# Out:
# 100.0

# %%
f=[[3,3,0,1,1,3,16,5,7]]
re=r.predict(f)
re
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([12])

# %%
import matplotlib.pyplot as plt

# %%
x=data["Restaurant"]
y=data["Food type"]
plt.bar(x,y)
plt.plot()
plt.show()
