# %%
import pandas as pd
data=pd.read_csv('C:\\Users\\DELL\\Numpy\stocks.csv')
data
# Out:
#     Ticker        Date        Open        High         Low       Close  \
# 0     AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1     AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2     AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3     AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4     AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
# ..     ...         ...         ...         ...         ...         ...
# 243   GOOG  2023-05-01  107.720001  108.680000  107.500000  107.709999
# 244   GOOG  2023-05-02  107.660004  107.730003  104.500000  105.980003
# 245   GOOG  2023-05-03  106.220001  108.129997  105.620003  106.120003
# 246   GOOG  2023-05-04  106.160004  106.300003  104.699997  105.209999
# 247   GOOG  2023-05-05  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 0    154.414230  83322600
# 1    151.688400  64120100
# 2    150.639999  56007100
# 3    151.009995  57450700
# 4    153.850006  62199000
# ..          ...       ...
# 243  107.709999  20926300
# 244  105.980003  20343100
# 245  106.120003  17116300
# 246  105.209999  19780600
# 247  106.214996  20705300
#
# [248 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# Ticker       0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Ticker', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj Close',
#        'Volume'],
#       dtype='object')

# %%
data.shape
# Out:
# (248, 8)

# %%
data.head(10)
# Out:
#   Ticker        Date        Open        High         Low       Close  \
# 0   AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1   AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2   AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3   AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4   AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
# 5   AAPL  2023-02-14  152.119995  153.770004  150.860001  153.199997
# 6   AAPL  2023-02-15  153.110001  155.500000  152.880005  155.330002
# 7   AAPL  2023-02-16  153.509995  156.330002  153.350006  153.710007
# 8   AAPL  2023-02-17  152.350006  153.000000  150.850006  152.550003
# 9   AAPL  2023-02-21  150.199997  151.300003  148.410004  148.479996
#
#     Adj Close    Volume
# 0  154.414230  83322600
# 1  151.688400  64120100
# 2  150.639999  56007100
# 3  151.009995  57450700
# 4  153.850006  62199000
# 5  153.199997  61707600
# 6  155.330002  65573800
# 7  153.710007  68167900
# 8  152.550003  59144100
# 9  148.479996  58867200

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler(feature_range=(0,1))
data[["Volume"]]=sc.fit_transform(data[["Volume"]])
data
# Out:
#     Ticker        Date        Open        High         Low       Close  \
# 0     AAPL  2023-02-07  150.639999  155.229996  150.639999  154.649994
# 1     AAPL  2023-02-08  153.880005  154.580002  151.169998  151.919998
# 2     AAPL  2023-02-09  153.779999  154.330002  150.419998  150.869995
# 3     AAPL  2023-02-10  149.460007  151.339996  149.220001  151.009995
# 4     AAPL  2023-02-13  150.949997  154.259995  150.919998  153.850006
# ..     ...         ...         ...         ...         ...         ...
# 243   GOOG  2023-05-01  107.720001  108.680000  107.500000  107.709999
# 244   GOOG  2023-05-02  107.660004  107.730003  104.500000  105.980003
# 245   GOOG  2023-05-03  106.220001  108.129997  105.620003  106.120003
# 246   GOOG  2023-05-04  106.160004  106.300003  104.699997  105.209999
# 247   GOOG  2023-05-05  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 0    154.414230  0.728952
# 1    151.688400  0.555422
# 2    150.639999  0.482107
# 3    151.009995  0.495152
# 4    153.850006  0.538062
# ..          ...       ...
# 243  107.709999  0.165088
# 244  105.980003  0.159818
# 245  106.120003  0.130658
# 246  105.209999  0.154735
# 247  106.214996  0.163091
#
# [248 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data1=['Ticker', 'Date', 'Open', 'High', 'Low', 'Close', 'Adj Close',
       'Volume']
for i in data1:
    data[i]=le.fit_transform(data[i])
data.head(10)
# Out:
#    Ticker  Date  Open  High  Low  Close  Adj Close  Volume
# 0       0     0    72    84   78     84         84     242
# 1       0     1    86    83   83     75         75     221
# 2       0     2    84    81   77     71         71     211
# 3       0     3    68    72   73     72         72     214
# 4       0     4    73    80   81     83         83     220
# 5       0     5    76    78   80     80         80     219
# 6       0     6    80    85   86     86         86     225
# 7       0     7    81    87   87     81         81     227
# 8       0     8    78    73   79     76         76     217
# 9       0     9    70    71   72     65         65     216

# %%
import matplotlib.pyplot as plt
import seaborn as sns
cor=data.corr()
sns.heatmap(cor,annot=True,cmap="viridis")
plt.show()

# %%
x=data.drop('Close',axis=1)
x.head(10)
# Out:
#    Ticker  Date  Open  High  Low  Adj Close  Volume
# 0       0     0    72    84   78         84     242
# 1       0     1    86    83   83         75     221
# 2       0     2    84    81   77         71     211
# 3       0     3    68    72   73         72     214
# 4       0     4    73    80   81         83     220
# 5       0     5    76    78   80         80     219
# 6       0     6    80    85   86         86     225
# 7       0     7    81    87   87         81     227
# 8       0     8    78    73   79         76     217
# 9       0     9    70    71   72         65     216

# %%
y=data['Close']
y.head(10)
# Out:
# 0    84
# 1    75
# 2    71
# 3    72
# 4    83
# 5    80
# 6    86
# 7    81
# 8    76
# 9    65
# Name: Close, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.29) 
regr=LinearRegression()

# %%
regr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=(regr.score(xtest,ytest)*100)
accuracy
# Out:
# 100.0

# %%
predict=(regr.score(xtrain,ytrain)*100)
predict
# Out:
# 100.0

# %%
v=[[0,2,84,81,77,71,211]]
w=regr.predict(v)
w
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([71.])

# %%
ypredict=regr.predict(xtest)
ypredict
# Out:
# array([156., 178.,  78.,  82.,  40., 158., 192.,  76.,   9., 149., 241.,
#        130., 210., 214., 198.,  19., 142., 195., 188.,  61., 116.,  31.,
#        206., 145., 106., 227., 216., 201., 163., 193., 202.,  46., 124.,
#        123., 132., 200., 107., 110., 222.,  59., 181., 182., 133.,  57.,
#        194.,  70.,  47.,   6., 164., 209., 135., 234., 172.,  88., 138.,
#        167.,  41., 220.,  12., 104.,  81.,  86., 223.,  83., 155., 186.,
#        204.,  14.,  50., 226., 215., 125.])

# %%
ytest
# Out:
# 97     156
# 148    178
# 20      78
# 18      82
# 246     40
#       ...
# 194     14
# 233     50
# 160    226
# 175    215
# 75     125
# Name: Close, Length: 72, dtype: int64

# %%
w1=ypredict.reshape(len(ypredict),1)
w1
# Out:
# array([[156.],
#        [178.],
#        [ 78.],
#        [ 82.],
#        [ 40.],
#        [158.],
#        [192.],
#        [ 76.],
#        [  9.],
#        [149.],
#        [241.],
#        [130.],
#        [210.],
#        [214.],
#        [198.],
#        [ 19.],
#        [142.],
#        [195.],
#        [188.],
#        [ 61.],
#        [116.],
#        [ 31.],
#        [206.],
#        [145.],
#        [106.],
#        [227.],
#        [216.],
#        [201.],
#        [163.],
#        [193.],
#        [202.],
#        [ 46.],
#        [124.],
#        [123.],
#        [132.],
#        [200.],
#        [107.],
#        [110.],
#        [222.],
#        [ 59.],
#        [181.],
#        [182.],
#        [133.],
#        [ 57.],
#        [194.],
#        [ 70.],
#        [ 47.],
#        [  6.],
#        [164.],
#        [209.],
#        [135.],
#        [234.],
#        [172.],
#        [ 88.],
#        [138.],
#        [167.],
#        [ 41.],
#        [220.],
#        [ 12.],
#        [104.],
#        [ 81.],
#        [ 86.],
#        [223.],
#        [ 83.],
#        [155.],
#        [186.],
#        [204.],
#        [ 14.],
#        [ 50.],
#        [226.],
#        [215.],
#        [125.]])

# %%
w2=ytest.values.reshape(len(ytest),1)
w2
# Out:
# array([[156],
#        [178],
#        [ 78],
#        [ 82],
#        [ 40],
#        [158],
#        [192],
#        [ 76],
#        [  9],
#        [149],
#        [241],
#        [130],
#        [210],
#        [214],
#        [198],
#        [ 19],
#        [142],
#        [195],
#        [188],
#        [ 61],
#        [116],
#        [ 31],
#        [206],
#        [145],
#        [106],
#        [227],
#        [216],
#        [201],
#        [163],
#        [193],
#        [202],
#        [ 46],
#        [124],
#        [123],
#        [132],
#        [200],
#        [107],
#        [110],
#        [222],
#        [ 59],
#        [181],
#        [182],
#        [133],
#        [ 57],
#        [194],
#        [ 70],
#        [ 47],
#        [  6],
#        [164],
#        [209],
#        [135],
#        [234],
#        [172],
#        [ 88],
#        [138],
#        [167],
#        [ 41],
#        [220],
#        [ 12],
#        [104],
#        [ 81],
#        [ 86],
#        [223],
#        [ 83],
#        [155],
#        [186],
#        [204],
#        [ 14],
#        [ 50],
#        [226],
#        [215],
#        [125]], dtype=int64)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(ytest,ypredict)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt

# %%
x=data["Open"]
y=data["Close"]
plt.scatter(x,y)
plt.xlabel("Open")
plt.ylabel("Close")
plt.show()
